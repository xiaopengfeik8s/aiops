# %% [markdown]
# # 微软 Graph RAG 运维知识库示例

# %%
# 安装 Graphrag
! pip install graphrag
# Out:
# Collecting graphrag
#   Obtaining dependency information for graphrag from https://files.pythonhosted.org/packages/72/bf/345c91e56bacca2c25e978de0d636aff76d5bc8bdae5ea7fa3375a670762/graphrag-0.2.2-py3-none-any.whl.metadata
#   Downloading graphrag-0.2.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiofiles<25.0.0,>=24.1.0 (from graphrag)
#   Obtaining dependency information for aiofiles<25.0.0,>=24.1.0 from https://files.pythonhosted.org/packages/a5/45/30bb92d442636f570cb5651bc661f52b610e2eec3f891a5dc3a4c3667db0/aiofiles-24.1.0-py3-none-any.whl.metadata
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from graphrag)
#   Obtaining dependency information for aiolimiter<2.0.0,>=1.1.0 from https://files.pythonhosted.org/packages/60/69/4b7dea755fafa10b248928da836a2cc8b5cff0762f363234e24218040f8e/aiolimiter-1.1.0-py3-none-any.whl.metadata
#   Downloading aiolimiter-1.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting azure-identity<2.0.0,>=1.17.1 (from graphrag)
#   Obtaining dependency information for azure-identity<2.0.0,>=1.17.1 from https://files.pythonhosted.org/packages/49/83/a777861351e7b99e7c84ff3b36bab35e87b6e5d36e50b6905e148c696515/azure_identity-1.17.1-py3-none-any.whl.metadata
#   Downloading azure_identity-1.17.1-py3-none-any.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 3.0 MB/s eta 0:00:00
# Collecting azure-search-documents<12.0.0,>=11.4.0 (from graphrag)
#   Obtaining dependency information for azure-search-documents<12.0.0,>=11.4.0 from https://files.pythonhosted.org/packages/e3/2a/115b3babcaa01f532d6527659acb042e9bbeab0afb5f7f6b5b53202bcec8/azure_search_documents-11.5.1-py3-none-any.whl.metadata
#   Downloading azure_search_documents-11.5.1-py3-none-any.whl.metadata (23 kB)
# Collecting azure-storage-blob<13.0.0,>=12.19.0 (from graphrag)
#   Obtaining dependency information for azure-storage-blob<13.0.0,>=12.19.0 from https://files.pythonhosted.org/packages/a8/52/b578c94048469fbf9f6378e2b2a46a2d0ccba3d59a7845dbed22ebf61601/azure_storage_blob-12.22.0-py3-none-any.whl.metadata
#   Downloading azure_storage_blob-12.22.0-py3-none-any.whl.metadata (26 kB)
# Collecting datashaper<0.0.50,>=0.0.49 (from graphrag)
#   Obtaining dependency information for datashaper<0.0.50,>=0.0.49 from https://files.pythonhosted.org/packages/cb/b9/f5cebf0fd2ebee6449663989f275f186928c92b94d05c9503c9ccc814757/datashaper-0.0.49-py3-none-any.whl.metadata
#   Downloading datashaper-0.0.49-py3-none-any.whl.metadata (3.7 kB)
# Collecting devtools<0.13.0,>=0.12.2 (from graphrag)
#   Obtaining dependency information for devtools<0.13.0,>=0.12.2 from https://files.pythonhosted.org/packages/d1/ae/afb1487556e2dc827a17097aac8158a25b433a345386f0e249f6d2694ccb/devtools-0.12.2-py3-none-any.whl.metadata
#   Downloading devtools-0.12.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting environs<12.0.0,>=11.0.0 (from graphrag)
#   Obtaining dependency information for environs<12.0.0,>=11.0.0 from https://files.pythonhosted.org/packages/3f/30/ef8a3022e6cdcedfd7ba03ca88ab29e30334f8e958cdbf5ce120912397e8/environs-11.0.0-py3-none-any.whl.metadata
#   Downloading environs-11.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting fastparquet<2025.0.0,>=2024.2.0 (from graphrag)
#   Obtaining dependency information for fastparquet<2025.0.0,>=2024.2.0 from https://files.pythonhosted.org/packages/63/79/7ccc7ad2c215b5468d3fd4a611ca851d94332e16a288e28b073a21c81bf2/fastparquet-2024.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading fastparquet-2024.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting graspologic<4.0.0,>=3.4.1 (from graphrag)
#   Obtaining dependency information for graspologic<4.0.0,>=3.4.1 from https://files.pythonhosted.org/packages/6a/0b/9a167cec9cc4555b59cd282e8669998a50cb3f929a9a503965b24fa58a20/graspologic-3.4.1-py3-none-any.whl.metadata
#   Downloading graspologic-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting json-repair<0.27.0,>=0.26.0 (from graphrag)
#   Obtaining dependency information for json-repair<0.27.0,>=0.26.0 from https://files.pythonhosted.org/packages/2a/cc/ba86e85e39c0c0171d64db2d2dc222d643240cf08c13dc2bdf48f8689108/json_repair-0.26.0-py3-none-any.whl.metadata
#   Downloading json_repair-0.26.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting lancedb<0.12.0,>=0.11.0 (from graphrag)
#   Obtaining dependency information for lancedb<0.12.0,>=0.11.0 from https://files.pythonhosted.org/packages/b5/ee/fff5af294dbce075a3568df3e5e8ffe0a719f1cb8f4ffccd649e668a08af/lancedb-0.11.0-cp38-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading lancedb-0.11.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: networkx<4,>=3 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (3.3)
# Collecting nltk==3.8.1 (from graphrag)
#   Obtaining dependency information for nltk==3.8.1 from https://files.pythonhosted.org/packages/a6/0a/0d20d2c0f16be91b9fa32a77b76c60f9baf6eba419e5ef5deca17af9c582/nltk-3.8.1-py3-none-any.whl.metadata
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting numba==0.60.0 (from graphrag)
#   Obtaining dependency information for numba==0.60.0 from https://files.pythonhosted.org/packages/65/42/39559664b2e7c15689a638c2a38b3b74c6e69a04e2b3019b9f7742479188/numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.37.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (1.40.0)
# Collecting pyaml-env<2.0.0,>=1.2.1 (from graphrag)
#   Obtaining dependency information for pyaml-env<2.0.0,>=1.2.1 from https://files.pythonhosted.org/packages/d7/9b/eb5d41a8ec8891ca85bac75b409d83f116b852fd46520f19c24464cba032/pyaml_env-1.2.1-py3-none-any.whl.metadata
#   Downloading pyaml_env-1.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic<3,>=2 (from graphrag)
#   Obtaining dependency information for pydantic<3,>=2 from https://files.pythonhosted.org/packages/1f/fa/b7f815b8c9ad021c07f88875b601222ef5e70619391ade4a49234d12d278/pydantic-2.8.2-py3-none-any.whl.metadata
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (1.0.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (6.0.1)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (13.7.1)
# Collecting scipy==1.12.0 (from graphrag)
#   Obtaining dependency information for scipy==1.12.0 from https://files.pythonhosted.org/packages/71/ba/744bbdd65eb3fce1412dd4633fc425ad39e6b4068b5b158aee1cd3afeb54/scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl.metadata
#   Downloading scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 10.6 MB/s eta 0:00:00
# Collecting swifter<2.0.0,>=1.4.0 (from graphrag)
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting tenacity<10.0.0,>=9.0.0 (from graphrag)
#   Obtaining dependency information for tenacity<10.0.0,>=9.0.0 from https://files.pythonhosted.org/packages/b6/cb/b86984bed139586d01532a587464b5805f12e397594f19f931c4c2fbfa61/tenacity-9.0.0-py3-none-any.whl.metadata
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting textual<0.75.0,>=0.74.0 (from graphrag)
#   Obtaining dependency information for textual<0.75.0,>=0.74.0 from https://files.pythonhosted.org/packages/20/7f/7c9d6338d7aaef0f809ff63928c268aa7122254cd06ea5cbb103184c4050/textual-0.74.0-py3-none-any.whl.metadata
#   Downloading textual-0.74.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (0.7.0)
# Collecting typing-extensions<5.0.0,>=4.12.2 (from graphrag)
#   Obtaining dependency information for typing-extensions<5.0.0,>=4.12.2 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: uvloop<0.20.0,>=0.19.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graphrag) (0.19.0)
# Requirement already satisfied: click in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from nltk==3.8.1->graphrag) (8.1.7)
# Requirement already satisfied: joblib in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from nltk==3.8.1->graphrag) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from nltk==3.8.1->graphrag) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from nltk==3.8.1->graphrag) (4.66.2)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba==0.60.0->graphrag)
#   Obtaining dependency information for llvmlite<0.44,>=0.43.0dev0 from https://files.pythonhosted.org/packages/a2/9c/24139d3712d2d352e300c39c0e00d167472c08b3bd350c3c33d72c88ff8d/llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting azure-core>=1.23.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Obtaining dependency information for azure-core>=1.23.0 from https://files.pythonhosted.org/packages/ef/d7/69d53f37733f8cb844862781767aef432ff3152bc9b9864dc98c7e286ce9/azure_core-1.30.2-py3-none-any.whl.metadata
#   Downloading azure_core-1.30.2-py3-none-any.whl.metadata (37 kB)
# Collecting cryptography>=2.5 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Obtaining dependency information for cryptography>=2.5 from https://files.pythonhosted.org/packages/66/d7/397515233e6a861f921bd0365b162b38e0cc513fcf4f1bdd9cc7bc5a3384/cryptography-43.0.0-cp39-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading cryptography-43.0.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.4 kB)
# Collecting msal>=1.24.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Obtaining dependency information for msal>=1.24.0 from https://files.pythonhosted.org/packages/ab/82/8f19334da43b7ef72d995587991a446f140346d76edb96a2c1a2689588e9/msal-1.30.0-py3-none-any.whl.metadata
#   Downloading msal-1.30.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=0.3.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Obtaining dependency information for msal-extensions>=0.3.0 from https://files.pythonhosted.org/packages/2c/69/314d887a01599669fb330da14e5c6ff5f138609e322812a942a74ef9b765/msal_extensions-1.2.0-py3-none-any.whl.metadata
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting azure-common>=1.1 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Obtaining dependency information for azure-common>=1.1 from https://files.pythonhosted.org/packages/62/55/7f118b9c1b23ec15ca05d15a578d8207aa1706bc6f7c87218efffbbf875d/azure_common-1.1.28-py2.py3-none-any.whl.metadata
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting isodate>=0.6.0 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Obtaining dependency information for isodate>=0.6.0 from https://files.pythonhosted.org/packages/b6/85/7882d311924cbcfc70b1890780763e36ff0b140c7e51c110fc59a532f087/isodate-0.6.1-py2.py3-none-any.whl.metadata
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting diskcache<6.0.0,>=5.6.3 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Obtaining dependency information for diskcache<6.0.0,>=5.6.3 from https://files.pythonhosted.org/packages/3f/27/4570e78fc0bf5ea0ca45eb1de3818a23787af9b390c0b0a0033a1b8236f9/diskcache-5.6.3-py3-none-any.whl.metadata
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from datashaper<0.0.50,>=0.0.49->graphrag) (4.23.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from datashaper<0.0.50,>=0.0.49->graphrag) (2.2.2)
# Collecting pyarrow<16.0.0,>=15.0.0 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Obtaining dependency information for pyarrow<16.0.0,>=15.0.0 from https://files.pythonhosted.org/packages/7b/cb/15f9c73da8e37253a5312b6803e77ef240eaf8e89e47e0310b020a5b94f0/pyarrow-15.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading pyarrow-15.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.4.1)
# Requirement already satisfied: executing>=1.1.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.0.1)
# Requirement already satisfied: pygments>=2.15.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.17.2)
# Requirement already satisfied: marshmallow>=3.13.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from environs<12.0.0,>=11.0.0->graphrag) (3.21.3)
# Collecting cramjam>=2.3 (from fastparquet<2025.0.0,>=2024.2.0->graphrag)
#   Obtaining dependency information for cramjam>=2.3 from https://files.pythonhosted.org/packages/ec/50/87d0f705401d6a754bcde63d2f1daaa2822935114a09f103fd885ae8ca3a/cramjam-2.8.3-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata
#   Downloading cramjam-2.8.3-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.2 kB)
# Requirement already satisfied: fsspec in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from fastparquet<2025.0.0,>=2024.2.0->graphrag) (2024.3.1)
# Requirement already satisfied: packaging in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from fastparquet<2025.0.0,>=2024.2.0->graphrag) (23.2)
# Collecting POT<0.10,>=0.9 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for POT<0.10,>=0.9 from https://files.pythonhosted.org/packages/81/9f/6269b9aa17b74a67f7f15fff713454336698e2f0e31ec7e592a681eeee55/POT-0.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading POT-0.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (32 kB)
# Collecting anytree<3.0.0,>=2.12.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for anytree<3.0.0,>=2.12.1 from https://files.pythonhosted.org/packages/6a/fb/ff946843e6b55ae9fda84df3964d6c233cd2261dface789f5be02ab79bc5/anytree-2.12.1-py3-none-any.whl.metadata
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting beartype<0.19.0,>=0.18.5 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for beartype<0.19.0,>=0.18.5 from https://files.pythonhosted.org/packages/64/43/7a1259741bd989723272ac7d381a43be932422abcff09a1d9f7ba212cb74/beartype-0.18.5-py3-none-any.whl.metadata
#   Downloading beartype-0.18.5-py3-none-any.whl.metadata (30 kB)
# Collecting gensim<5.0.0,>=4.3.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for gensim<5.0.0,>=4.3.2 from https://files.pythonhosted.org/packages/1f/76/616bc781bc19ee76b387a101211f73e00cf59368fcc221e77f88ea907d04/gensim-4.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading gensim-4.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting graspologic-native<2.0.0,>=1.2.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for graspologic-native<2.0.0,>=1.2.1 from https://files.pythonhosted.org/packages/55/74/e95efeb87336f16765a941c9057528fedee7f2d4679b380ebc008c4833f7/graspologic_native-1.2.1-cp36-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata
#   Downloading graspologic_native-1.2.1-cp36-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.9 kB)
# Collecting hyppo<0.5.0,>=0.4.0 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for hyppo<0.5.0,>=0.4.0 from https://files.pythonhosted.org/packages/34/87/7940713f929d0280cff1bde207479cb588a0d3a4dd49a0e2e69bfff46363/hyppo-0.4.0-py3-none-any.whl.metadata
#   Downloading hyppo-0.4.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting joblib (from nltk==3.8.1->graphrag)
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.4 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (3.9.0)
# Collecting scikit-learn<2.0.0,>=1.4.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for scikit-learn<2.0.0,>=1.4.2 from https://files.pythonhosted.org/packages/d5/2c/734fc9269bdb6768905ac41b82d75264b26925b1e462f4ebf45fe4f17646/scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (12 kB)
# Collecting seaborn<0.14.0,>=0.13.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for seaborn<0.14.0,>=0.13.2 from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting statsmodels<0.15.0,>=0.14.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for statsmodels<0.15.0,>=0.14.2 from https://files.pythonhosted.org/packages/e7/fd/d282f6a0a55c5903dd66c2116589d1973a352739653382c39d70dcfd0fbc/statsmodels-0.14.2-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading statsmodels-0.14.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting umap-learn<0.6.0,>=0.5.6 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for umap-learn<0.6.0,>=0.5.6 from https://files.pythonhosted.org/packages/d1/1b/46802a050b1c55d10c4f59fc6afd2b45ac9b4f62b2e12092d3f599286f14/umap_learn-0.5.6-py3-none-any.whl.metadata
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting deprecation (from lancedb<0.12.0,>=0.11.0->graphrag)
#   Obtaining dependency information for deprecation from https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl.metadata
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pylance==0.15.0 (from lancedb<0.12.0,>=0.11.0->graphrag)
#   Obtaining dependency information for pylance==0.15.0 from https://files.pythonhosted.org/packages/39/37/4542a8b63ea9e146cdf601d83037b7983ce548e6e1c83b9d02e774845155/pylance-0.15.0-cp39-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading pylance-0.15.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Collecting ratelimiter~=1.0 (from lancedb<0.12.0,>=0.11.0->graphrag)
#   Obtaining dependency information for ratelimiter~=1.0 from https://files.pythonhosted.org/packages/51/80/2164fa1e863ad52cc8d870855fba0fbb51edd943edffd516d54b5f6f8ff8/ratelimiter-1.2.0.post0-py3-none-any.whl.metadata
#   Downloading ratelimiter-1.2.0.post0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: requests>=2.31.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from lancedb<0.12.0,>=0.11.0->graphrag) (2.31.0)
# Collecting retry>=0.9.2 (from lancedb<0.12.0,>=0.11.0->graphrag)
#   Obtaining dependency information for retry>=0.9.2 from https://files.pythonhosted.org/packages/4b/0d/53aea75710af4528a25ed6837d71d117602b01946b307a3912cb3cfcbcba/retry-0.9.2-py2.py3-none-any.whl.metadata
#   Downloading retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: attrs>=21.3.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from lancedb<0.12.0,>=0.11.0->graphrag) (23.2.0)
# Requirement already satisfied: cachetools in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from lancedb<0.12.0,>=0.11.0->graphrag) (5.3.3)
# Requirement already satisfied: overrides>=0.7 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from lancedb<0.12.0,>=0.11.0->graphrag) (7.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai<2.0.0,>=1.37.1->graphrag) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai<2.0.0,>=1.37.1->graphrag) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai<2.0.0,>=1.37.1->graphrag) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai<2.0.0,>=1.37.1->graphrag) (0.5.0)
# Requirement already satisfied: sniffio in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai<2.0.0,>=1.37.1->graphrag) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pydantic<3,>=2->graphrag) (0.6.0)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=2->graphrag)
#   Obtaining dependency information for pydantic-core==2.20.1 from https://files.pythonhosted.org/packages/6a/23/430f2878c9cd977a61bb39f71751d9310ec55cee36b3d5bf1752c6341fd0/pydantic_core-2.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading pydantic_core-2.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from rich<14.0.0,>=13.6.0->graphrag) (3.0.0)
# Requirement already satisfied: psutil>=5.6.6 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from swifter<2.0.0,>=1.4.0->graphrag) (5.9.8)
# Collecting dask[dataframe]>=2.10.0 (from swifter<2.0.0,>=1.4.0->graphrag)
#   Obtaining dependency information for dask[dataframe]>=2.10.0 from https://files.pythonhosted.org/packages/db/47/136a5dd68a33089f96f8aa1178ccd545d325ec9ab2bb42a3038711a935c0/dask-2024.8.0-py3-none-any.whl.metadata
#   Downloading dask-2024.8.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: idna>=2.8 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.37.1->graphrag) (3.6)
# Requirement already satisfied: six in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from anytree<3.0.0,>=2.12.1->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (1.16.0)
# Collecting cloudpickle>=1.5.0 (from dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag)
#   Obtaining dependency information for cloudpickle>=1.5.0 from https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting partd>=1.4.0 (from dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag)
#   Obtaining dependency information for partd>=1.4.0 from https://files.pythonhosted.org/packages/71/e7/40fb618334dcdf7c5a316c0e7343c5cd82d3d866edc100d98e29bc945ecd/partd-1.4.2-py3-none-any.whl.metadata
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: toolz>=0.10.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (0.12.1)
# Collecting dask-expr<1.2,>=1.1 (from dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag)
#   Obtaining dependency information for dask-expr<1.2,>=1.1 from https://files.pythonhosted.org/packages/2c/e3/cf7a05892b04b22b9e28ec25f8bc2acaa0304bf3128f76031e4363b63e21/dask_expr-1.1.10-py3-none-any.whl.metadata
#   Downloading dask_expr-1.1.10-py3-none-any.whl.metadata (2.5 kB)
# Collecting smart-open>=1.8.1 (from gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for smart-open>=1.8.1 from https://files.pythonhosted.org/packages/65/12/cc24847b4b0b124501a33cd8f7963f79f6f6584bc7f2f4fc16bbbaa54c8f/smart_open-7.0.4-py3-none-any.whl.metadata
#   Downloading smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: certifi in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.37.1->graphrag) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.37.1->graphrag) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.37.1->graphrag) (0.14.0)
# Collecting autograd>=1.3 (from hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for autograd>=1.3 from https://files.pythonhosted.org/packages/81/70/d5c7c2a458b8be96495c8b1634c2155beab58cbe864b7a9a5c06c2e52520/autograd-1.6.2-py3-none-any.whl.metadata
#   Downloading autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (0.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (2.8.2)
# Collecting PyJWT[crypto]<3,>=1.0.0 (from msal>=1.24.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Obtaining dependency information for PyJWT[crypto]<3,>=1.0.0 from https://files.pythonhosted.org/packages/79/84/0fdf9b18ba31d69877bd39c9cd6052b47f3761e9910c15de788e519f079f/PyJWT-2.9.0-py3-none-any.whl.metadata
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Obtaining dependency information for portalocker<3,>=1.4 from https://files.pythonhosted.org/packages/9b/fb/a70a4214956182e0d7a9099ab17d50bfcba1056188e9b14f35b9e2b62a0d/portalocker-2.10.1-py3-none-any.whl.metadata
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.0->datashaper<0.0.50,>=0.0.49->graphrag) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.0->datashaper<0.0.50,>=0.0.49->graphrag) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.31.0->lancedb<0.12.0,>=0.11.0->graphrag) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.31.0->lancedb<0.12.0,>=0.11.0->graphrag) (2.2.2)
# Requirement already satisfied: decorator>=3.4.2 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from retry>=0.9.2->lancedb<0.12.0,>=0.11.0->graphrag) (4.4.2)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb<0.12.0,>=0.11.0->graphrag)
#   Obtaining dependency information for py<2.0.0,>=1.4.26 from https://files.pythonhosted.org/packages/f6/f0/10642828a8dfb741e5f3fbaac830550a518a775c7fff6f04a007259b0548/py-1.11.0-py2.py3-none-any.whl.metadata
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.4.2->graspologic<4.0.0,>=3.4.1->graphrag) (3.4.0)
# Collecting patsy>=0.5.6 (from statsmodels<0.15.0,>=0.14.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for patsy>=0.5.6 from https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl.metadata
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pynndescent>=0.5 (from umap-learn<0.6.0,>=0.5.6->graspologic<4.0.0,>=3.4.1->graphrag)
#   Obtaining dependency information for pynndescent>=0.5 from https://files.pythonhosted.org/packages/d2/53/d23a97e0a2c690d40b165d1062e2c4ccc796be458a1ce59f6ba030434663/pynndescent-0.5.13-py3-none-any.whl.metadata
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: future>=0.15.2 in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from autograd>=1.3->hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag) (1.0.0)
# Requirement already satisfied: pycparser in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (2.22)
# Requirement already satisfied: uc-micro-py in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from linkify-it-py<3,>=1->markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (1.0.3)
# Collecting locket (from partd>=1.4.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag)
#   Obtaining dependency information for locket from https://files.pythonhosted.org/packages/db/bc/83e112abc66cd466c6b83f99118035867cecd41802f8d044638aa78a106e/locket-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: wrapt in /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Downloading graphrag-0.2.2-py3-none-any.whl (371 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.4/371.4 kB 41.7 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.9 MB/s eta 0:00:00
# Downloading numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 50.1 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 9.1 MB/s eta 0:00:0000:0100:01m
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiolimiter-1.1.0-py3-none-any.whl (7.2 kB)
# Downloading azure_identity-1.17.1-py3-none-any.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 kB 17.8 MB/s eta 0:00:00
# Downloading azure_search_documents-11.5.1-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.7/297.7 kB 18.7 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.22.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.9/404.9 kB 49.3 MB/s eta 0:00:00
# Downloading datashaper-0.0.49-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 10.5 MB/s eta 0:00:00
# Downloading devtools-0.12.2-py3-none-any.whl (19 kB)
# Downloading environs-11.0.0-py3-none-any.whl (12 kB)
# Downloading fastparquet-2024.5.0-cp312-cp312-macosx_11_0_arm64.whl (685 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 685.1/685.1 kB 40.0 MB/s eta 0:00:00
# Downloading graspologic-3.4.1-py3-none-any.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 54.6 MB/s eta 0:00:00a 0:00:01
# Downloading json_repair-0.26.0-py3-none-any.whl (12 kB)
# Downloading lancedb-0.11.0-cp38-abi3-macosx_11_0_arm64.whl (18.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 56.1 MB/s eta 0:00:0000:0100:01
# Downloading pylance-0.15.0-cp39-abi3-macosx_11_0_arm64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 52.4 MB/s eta 0:00:0000:0100:01
# Downloading pyaml_env-1.2.1-py3-none-any.whl (9.0 kB)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 40.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.1 MB/s eta 0:00:00a 0:00:01
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading textual-0.74.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.5/566.5 kB 31.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 5.6 MB/s eta 0:00:00
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 27.9 MB/s eta 0:00:00
# Downloading beartype-0.18.5-py3-none-any.whl (917 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.8/917.8 kB 47.7 MB/s eta 0:00:00
# Downloading cramjam-2.8.3-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 1.7 MB/s eta 0:00:00a 0:00:01m
# Downloading cryptography-43.0.0-cp39-abi3-macosx_10_9_universal2.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 58.4 MB/s eta 0:00:00a 0:00:01
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.5 MB/s eta 0:00:00
# Downloading gensim-4.3.3-cp312-cp312-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 4.9 MB/s eta 0:00:0000:0100:01
# Downloading graspologic_native-1.2.1-cp36-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (660 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.1/660.1 kB 30.6 MB/s eta 0:00:00
# Downloading hyppo-0.4.0-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 20.4 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.1 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 25.4 MB/s eta 0:00:00
# Downloading llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 16.0 MB/s eta 0:00:0000:0100:01
# Downloading msal-1.30.0-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 5.0 MB/s eta 0:00:00
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Downloading POT-0.9.4-cp312-cp312-macosx_11_0_arm64.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 kB 18.6 MB/s eta 0:00:00
# Downloading pyarrow-15.0.2-cp312-cp312-macosx_11_0_arm64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 59.7 MB/s eta 0:00:0000:0100:01
# Downloading ratelimiter-1.2.0.post0-py3-none-any.whl (6.6 kB)
# Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Downloading scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 111.0 MB/s eta 0:00:000:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.3 MB/s eta 0:00:00ta 0:00:01
# Downloading statsmodels-0.14.2-cp312-cp312-macosx_11_0_arm64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 64.9 MB/s eta 0:00:0000:010:01
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 9.8 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading autograd-1.6.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.5 MB/s eta 0:00:00
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading dask_expr-1.1.10-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 kB 23.1 MB/s eta 0:00:00
# Downloading dask-2024.8.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 75.2 MB/s eta 0:00:00
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 24.7 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 14.0 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 8.2 MB/s eta 0:00:00
# Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 7.2 MB/s eta 0:00:00
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16507 sha256=c795ad8b34b08cb23bcd411a977568ae647fa114c8a9abd319b0361d6ebbe608
#   Stored in directory: /Users/wangwei/Library/Caches/pip/wheels/d9/31/ff/ff51141a088571a9f672449e5aad5ea8bb35ca5d95ba135f30
# Successfully built swifter
# Installing collected packages: ratelimiter, azure-common, typing-extensions, tenacity, smart-open, scipy, PyJWT, pyarrow, pyaml-env, py, portalocker, patsy, locket, llvmlite, json-repair, joblib, isodate, graspologic-native, diskcache, deprecation, cramjam, cloudpickle, beartype, autograd, anytree, aiolimiter, aiofiles, scikit-learn, retry, pylance, pydantic-core, POT, partd, numba, nltk, gensim, environs, devtools, cryptography, azure-core, statsmodels, seaborn, pynndescent, pydantic, hyppo, fastparquet, dask, azure-storage-blob, azure-search-documents, umap-learn, textual, msal, lancedb, datashaper, dask-expr, msal-extensions, graspologic, swifter, azure-identity, graphrag
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.4.2
#     Uninstalling tenacity-8.4.2:
#       Successfully uninstalled tenacity-8.4.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.0
#     Uninstalling scipy-1.13.0:
#       Successfully uninstalled scipy-1.13.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.0.0
#     Uninstalling pyarrow-16.0.0:
#       Successfully uninstalled pyarrow-16.0.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.42.0
#     Uninstalling llvmlite-0.42.0:
#       Successfully uninstalled llvmlite-0.42.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 23.2.1
#     Uninstalling aiofiles-23.2.1:
#       Successfully uninstalled aiofiles-23.2.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.1.post1
#     Uninstalling scikit-learn-1.4.1.post1:
#       Successfully uninstalled scikit-learn-1.4.1.post1
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.3
#     Uninstalling pydantic_core-2.16.3:
#       Successfully uninstalled pydantic_core-2.16.3
#   Attempting uninstall: numba
#     Found existing installation: numba 0.59.1
#     Uninstalling numba-0.59.1:
#       Successfully uninstalled numba-0.59.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.17
#     Uninstalling pydantic-1.10.17:
#       Successfully uninstalled pydantic-1.10.17
#   Attempting uninstall: textual
#     Found existing installation: textual 0.63.0
#     Uninstalling textual-0.63.0:
#       Successfully uninstalled textual-0.63.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.2.12 requires tenacity!=8.4.0,<9.0.0,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.
# gradio 3.50.2 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# langchain-community 0.2.11 requires tenacity!=8.4.0,<9.0.0,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.
# langchain-core 0.2.28 requires tenacity!=8.4.0,<9.0.0,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.
# Successfully installed POT-0.9.4 PyJWT-2.9.0 aiofiles-24.1.0 aiolimiter-1.1.0 anytree-2.12.1 autograd-1.6.2 azure-common-1.1.28 azure-core-1.30.2 azure-identity-1.17.1 azure-search-documents-11.5.1 azure-storage-blob-12.22.0 beartype-0.18.5 cloudpickle-3.0.0 cramjam-2.8.3 cryptography-43.0.0 dask-2024.8.0 dask-expr-1.1.10 datashaper-0.0.49 deprecation-2.1.0 devtools-0.12.2 diskcache-5.6.3 environs-11.0.0 fastparquet-2024.5.0 gensim-4.3.3 graphrag-0.2.2 graspologic-3.4.1 graspologic-native-1.2.1 hyppo-0.4.0 isodate-0.6.1 joblib-1.4.2 json-repair-0.26.0 lancedb-0.11.0 llvmlite-0.43.0 locket-1.0.0 msal-1.30.0 msal-extensions-1.2.0 nltk-3.8.1 numba-0.60.0 partd-1.4.2 patsy-0.5.6 portalocker-2.10.1 py-1.11.0 pyaml-env-1.2.1 pyarrow-15.0.2 pydantic-2.8.2 pydantic-core-2.20.1 pylance-0.15.0 pynndescent-0.5.13 ratelimiter-1.2.0.post0 retry-0.9.2 scikit-learn-1.5.1 scipy-1.12.0 seaborn-0.13.2 smart-open-7.0.4 statsmodels-0.14.2 swifter-1.4.0 tenacity-9.0.0 textual-0.74.0 typing-extensions-4.12.2 umap-learn-0.5.6
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# 首次运行需要设置工作区
! python -m graphrag.index --init --root ./data
# Out:
# Initializing project at ./data
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File Indexer
# "/Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/graphrag/ind
# ex/__main__.py", line 76, in <module>
#     index_cli(
#   File Indexer
# "/Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/graphrag/ind
# ex/cli.py", line 90, in index_cli
#     _initialize_project_at(root, progress_reporter)
#   File Indexer
# "/Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/graphrag/ind
# ex/cli.py", line 184, in _initialize_project_at
#     raise ValueError(msg)
# ValueError: Project already initialized at data
# ⠋ GraphRAG Indexer

# %%
# 设置必要的环境变量
# 编辑 .env 文件，设置以下环境变量
# GRAPHRAG_API_KEY=
# GRAPHRAG_API_BASE=

# 修改 settings.yaml 文件 llm 和 embeddings 参数。
! mkdir ./data/input
# 将知识库文档放入 ./data/input 目录下

# %%
# 建立 Graphrag 索引
! python -m graphrag.index --root ./data
# Out:
# 🚀 Reading settings from data/settings.yaml
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# └── create_base_text_units
# 🚀 create_base_text_units━━   0% -:--:-- 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
#                                  id  ... n_tokens
# 0  fffadfecd590702a9327e7204f05e7a6  ...     1181
# 1  55121b31ebb2f7160a384fe289d43753  ...       81
#
# [2 rows x 5 columns]
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:05
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:07
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠦ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:08
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠏ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:09
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:10
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:11
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:12
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠦ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:13
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# 🚀 create_base_extracted_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠹ GraphRAG Indexer ╸━  93% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠼ GraphRAG Indexer ╸━  93% 0:00:01 0:00:01
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠇ GraphRAG Indexer ╺  96% 0:00:01 0:00:01
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠸ GraphRAG Indexer ╸  98% 0:00:01 0:00:01
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# 🚀 create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# 🚀 create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
#    level                                    clustered_graph
# 0      0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠇ GraphRAG Indexer  -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠋ GraphRAG Indexer  -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠙ GraphRAG Indexer ━━━  50% -:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# 🚀 create_final_entities-- 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
#                                   id  ...
# description_embedding
# 0   b45241d70f0e43fca764df95b2b81f77  ...  [-0.021454989910125732,
# -0.021261798217892647,...
# 1   4119fd06010c494caa07f439b333f4c5  ...  [-0.018851540982723236,
# -0.0381864532828331, 0...
# 2   d3835bf3dda84ead99deadbeac5d0d7d  ...  [-0.024349763989448547,
# -0.04183567315340042, ...
# 3   077d2820ae1845bcbb1803379a3d1eae  ...  [0.0043024942278862,
# -0.041073355823755264, 0....
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac  ...  [-0.03158412128686905,
# 0.019376903772354126, 0...
# 5   19a7f254a5d64566ab5cc15472df02de  ...  [-0.024922683835029602,
# 0.00041696347761899233...
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e  ...  [0.004473328124731779,
# -0.030100898817181587, ...
# 7   f7e11b0e297a44a896dc67928368f600  ...  [-0.05089442431926727,
# 0.020467013120651245, 0...
# 8   1fd3fa8bb5a2408790042ab9573779ee  ...  [-0.0020457589998841286,
# 0.0415956974029541, 0...
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c  ...  [-0.04031004384160042,
# -0.014739536680281162, ...
# 10  e1fd0e904a53409aada44442f23a51cb  ...  [-0.02045663446187973,
# 0.02939612790942192, 0....
# 11  de988724cfdf45cebfba3b13c43ceede  ...  [-0.0006013057427480817,
# 0.013436507433652878,...
# 12  96aad7cb4b7d40e9b7e13b94a67af206  ...  [0.023610787466168404,
# 0.019756760448217392, 0...
# 13  c9632a35146940c2a86167c7726d35e9  ...  [-0.03369877114892006,
# 0.03081262670457363, 0....
# 14  9646481f66ce4fd2b08c2eddda42fc82  ...  [0.011512474156916142,
# 0.05829276889562607, 0....
# 15  d91a266f766b4737a06b0fda588ba40b  ...  [0.00494786910712719,
# 0.027164770290255547, 0....
# 16  bc0e3f075a4c4ebbb7c7b152b65a5625  ...  [-0.04807255417108536,
# 0.048927292227745056, 0...
# 17  254770028d7a4fa9877da4ba0ad5ad21  ...  [-0.019829753786325455,
# 0.04383671656250954, 0...
# 18  4a67211867e5464ba45126315a122a8a  ...  [-0.05308146774768829,
# 0.058607619255781174, 0...
# 19  04dbbb2283b845baaeac0eaf0c34c9da  ...  [0.0001678341068327427,
# 0.03692508116364479, 0...
# 20  1943f245ee4243bdbfbd2fd619ae824a  ...  [-0.0011767225805670023,
# 0.030246717855334282,...
# 21  273daeec8cad41e6b3e450447db58ee7  ...  [0.012407173402607441,
# 0.030797619372606277, -...
# 22  e69dc259edb944ea9ea41264b9fcfe59  ...  [0.0032224825117737055,
# 0.047077275812625885, ...
# 23  e2f5735c7d714423a2c4f61ca2644626  ...  [0.010249911807477474,
# 0.0032485290430486202, ...
# 24  deece7e64b2a4628850d4bb6e394a9c3  ...  [0.026477549225091934,
# 0.019156360998749733, 0...
# 25  e657b5121ff8456b9a610cfaead8e0cb  ...  [0.023829389363527298,
# -0.016909925267100334, ...
# 26  bf4e255cdac94ccc83a56435a5e4b075  ...  [-0.002972301794216037,
# 0.049165621399879456, ...
# 27  3b040bcc19f14e04880ae52881a89c1c  ...  [-0.027713187038898468,
# -0.027689997106790543,...
# 28  3d6b216c14354332b1bf1927ba168986  ...  [-0.019376609474420547,
# -0.022065017372369766,...
# 29  1c109cfdc370463eb6d537e5b7b382fb  ...  [0.0008521387935616076,
# -0.03271305561065674, ...
# 30  3d0dcbc8971b415ea18065edc4d8c8ef  ...  [-0.020189987495541573,
# -0.0149241853505373, 0...
#
# [31 rows x 8 columns]
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠼ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/datashaper/en
# gine/verbs/convert.py:72: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_datetime without passing `errors` and catch
# exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/datashaper/en
# gine/verbs/convert.py:72: UserWarning: Could not infer format, so each element
# will be parsed individually, falling back to `dateutil`. To ensure parsing is
# consistent and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠴ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# 🚀 create_final_nodes
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
#     level             title  ...  x  y
# 0       0              支付系统  ...  0  0
# 1       0                小张  ...  0  0
# 2       0                小王  ...  0  0
# 3       0                小李  ...  0  0
# 4       0              技术支持  ...  0  0
# 5       0              紧急联系  ...  0  0
# 6       0              客服热线  ...  0  0
# 7       0              响应时间  ...  0  0
# 8       0              系统负载  ...  0  0
# 9       0              交易失败  ...  0  0
# 10      0              系统宕机  ...  0  0
# 11      0              安全问题  ...  0  0
# 12      0              数据备份  ...  0  0
# 13      0              系统更新  ...  0  0
# 14      0              性能调优  ...  0  0
# 15      0              发现问题  ...  0  0
# 16      0              快速响应  ...  0  0
# 17      0              问题定位  ...  0  0
# 18      0              解决方案  ...  0  0
# 19      0              问题解决  ...  0  0
# 20      0              后续跟进  ...  0  0
# 21      0              代码优化  ...  0  0
# 22      0              资源扩展  ...  0  0
# 23      0              负载均衡  ...  0  0
# 24      0              访问控制  ...  0  0
# 25      0              数据加密  ...  0  0
# 26      0              安全审计  ...  0  0
# 27      0  PAYMENT FRONTEND  ...  0  0
# 28      0   PAYMENT GATEWAY  ...  0  0
# 29      0  PAYMENT CALLBACK  ...  0  0
# 30      0   PAYMENT BACKEND  ...  0  0
#
# [31 rows x 14 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠇ GraphRAG Indexer  0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠇ GraphRAG Indexer  0:00:00
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# 🚀 create_final_communities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
#   id  ...                                      text_unit_ids
# 0  2  ...
# 1  0  ...  [55121b31ebb2f7160a384fe289d43753,fffadfecd590...
# 2  1  ...  [55121b31ebb2f7160a384fe289d43753,fffadfecd590...
#
# [3 rows x 6 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# 🚀 join_text_units_to_entity_ids
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
#                       text_unit_ids  ...                                id
# 0  fffadfecd590702a9327e7204f05e7a6  ...  fffadfecd590702a9327e7204f05e7a6
# 1  55121b31ebb2f7160a384fe289d43753  ...  55121b31ebb2f7160a384fe289d43753
#
# [2 rows x 3 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠸ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠼ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/datashaper/en
# gine/verbs/convert.py:65: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_numeric without passing `errors` and catch
# exceptions explicitly instead
#   column_numeric = cast(pd.Series, pd.to_numeric(column, errors="ignore"))
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠼ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# 🚀 create_final_relationships
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
#               source            target  ...  target_degree rank
# 0               支付系统                小张  ...              5   11
# 1               支付系统                小王  ...              4   10
# 2               支付系统                小李  ...              4   10
# 3               支付系统              技术支持  ...              1    7
# 4               支付系统              紧急联系  ...              1    7
# 5               支付系统              客服热线  ...              1    7
# 6                 小张                小王  ...              4    9
# 7                 小张                小李  ...              4    9
# 8                 小张   PAYMENT BACKEND  ...              2    7
# 9                 小张  PAYMENT FRONTEND  ...              2    7
# 10                小王                小李  ...              4    8
# 11                小王   PAYMENT GATEWAY  ...              2    6
# 12                小李  PAYMENT CALLBACK  ...              2    6
# 13  PAYMENT FRONTEND   PAYMENT BACKEND  ...              2    4
# 14   PAYMENT GATEWAY  PAYMENT CALLBACK  ...              2    4
#
# [15 rows x 10 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# 🚀 join_text_units_to_relationship_ids
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
#                                  id
# relationship_ids
# 0  fffadfecd590702a9327e7204f05e7a6  [68105770b523412388424d984e711917,
# 85c79fd84f5...
# 1  55121b31ebb2f7160a384fe289d43753  [e2bf260115514fb3b252fd879fb3e7be,
# b462b94ce47...
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠧ GraphRAG Indexer :05
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠋ GraphRAG Indexer :05
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠦ GraphRAG Indexer :06
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠸ GraphRAG Indexer :06
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠦ GraphRAG Indexer :07
# ...
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠦ GraphRAG Indexer :14
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# └── create_final_community_reports
# ⠙ GraphRAG Indexer :15
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# 🚀 create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
#   community  ...                                    id
# 0         0  ...  d5dcd142-c93c-477a-bf3b-5678511bff03
# 1         1  ...  7a47ad27-1a4b-4c1c-964c-4f465b8eb302
# 2         2  ...  ddd52d63-5021-4246-a6f5-6a7b25012f64
#
# [3 rows x 10 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# 🚀 create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
#                                  id  ...
# relationship_ids
# 0  fffadfecd590702a9327e7204f05e7a6  ...  [68105770b523412388424d984e711917,
# 85c79fd84f5...
# 1  55121b31ebb2f7160a384fe289d43753  ...  [e2bf260115514fb3b252fd879fb3e7be,
# b462b94ce47...
#
# [2 rows x 6 columns]
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# /Users/wangwei/.pyenv/versions/3.12.0/lib/python3.12/site-packages/datashaper/en
# gine/verbs/convert.py:72: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_datetime without passing `errors` and catch
# exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# 🚀 create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
#                                  id  ...     title
# 0  f6aaca4727b79e1aaf291e4c20cade6b  ...  data.txt
#
# [1 rows x 4 columns]
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# 🚀 create_final_documents
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
#                                  id  ...     title
# 0  f6aaca4727b79e1aaf291e4c20cade6b  ...  data.txt
#
# [1 rows x 4 columns]
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
# 查询
! python -m graphrag.query \
--root ./data \
--method global \
"谁负责的业务最多？"
# Out:
# INFO: Reading settings from data/settings.yaml
# creating llm client with {'api_key': 'REDACTED,len=51', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': 'https://api.apiyi.com/v1', 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Global Search Response: ## 业务管理概述
#
# 在当前的支付系统管理中，小张负责的业务最多。他管理着支付系统的后端和前端操作，确保支付流程的顺利进行。这一角色使得他在支付操作社区中扮演了关键角色，直接影响着客户满意度和业务收入 [Data: Reports (0, 1)]。
#
# ## 其他相关角色
#
# 相比之下，小李和小王分别负责支付回调和支付网关操作。虽然他们的角色也很重要，但相较于小张，他们的管理范围较小 [Data: Reports (1)]。这表明小张在整体业务管理中占据了更为重要的地位。
#
# ## 结论
#
# 综上所述，小张在支付系统的管理中承担了最多的责任，这不仅影响了支付流程的效率，也对客户体验和公司收入产生了重要影响。

# %%
# 启动 Neo4j 查看实体关系
! docker run -d \
    -p 7474:7474 -p 7687:7687 \
    --name neo4j-apoc \
    -e NEO4J_apoc_export_file_enabled=true \
    -e NEO4J_apoc_import_file_enabled=true \
    -e NEO4J_apoc_import_file_use__neo4j__config=true \
    -e NEO4J_PLUGINS=\[\"apoc\"\] \
    neo4j:5.21.2
# Out:
# 运行具有“Python 3.12.2”的单元格需要ipykernel包。
#
# 运行以下命令，将 "ipykernel" 安装到 Python 环境中。
#
# 命令: "/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall"

# %% [markdown]
# 访问：http://localhost:7474/，输入默认账号密码 neo4j/neo4j，按照修改密码为：mypassword

# %%
! pip install --quiet pandas neo4j-rust-ext
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from neo4j import GraphDatabase
import time

# 修改为你的 Graphrag 输出目录
GRAPHRAG_FOLDER = "./data/output/20240810-142243/artifacts"

NEO4J_URI = "neo4j://localhost"  # or neo4j+s://xxxx.databases.neo4j.io
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "mypassword"
NEO4J_DATABASE = "neo4j"

# Create a Neo4j driver
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

statements = """
create constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique;
create constraint document_id if not exists for (d:__Document__) require d.id is unique;
create constraint entity_id if not exists for (c:__Community__) require c.community is unique;
create constraint entity_id if not exists for (e:__Entity__) require e.id is unique;
create constraint entity_title if not exists for (e:__Entity__) require e.name is unique;
create constraint entity_title if not exists for (e:__Covariate__) require e.title is unique;
create constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique;
""".split(";")

for statement in statements:
    if len((statement or "").strip()) > 0:
        print(statement)
        driver.execute_query(statement)


def batched_import(statement, df, batch_size=1000):
    """
    Import a dataframe into Neo4j using a batched approach.
    Parameters: statement is the Cypher query to execute, df is the dataframe to import, and batch_size is the number of rows to import in each batch.
    """
    total = len(df)
    start_s = time.time()
    for start in range(0,total, batch_size):
        batch = df.iloc[start: min(start+batch_size,total)]
        result = driver.execute_query("UNWIND $rows AS value " + statement, 
                                      rows=batch.to_dict('records'),
                                      database_=NEO4J_DATABASE)
        print(result.summary.counters)
    print(f'{total} rows in { time.time() - start_s} s.')    
    return total

doc_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_documents.parquet', columns=["id", "title"])
doc_df.head(2)

# import documents
statement = """
MERGE (d:__Document__ {id:value.id})
SET d += value {.title}
"""

batched_import(statement, doc_df)

text_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_text_units.parquet',
                          columns=["id","text","n_tokens","document_ids"])
text_df.head(2)

statement = """
MERGE (c:__Chunk__ {id:value.id})
SET c += value {.text, .n_tokens}
WITH c, value
UNWIND value.document_ids AS document
MATCH (d:__Document__ {id:document})
MERGE (c)-[:PART_OF]->(d)
"""

batched_import(statement, text_df)

entity_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_entities.parquet',
                            columns=["name", "type", "description", "human_readable_id", "id", "description_embedding",
                                     "text_unit_ids"])
entity_df.head(2)

entity_statement = """
MERGE (e:__Entity__ {id:value.id})
SET e += value {.human_readable_id, .description, name:replace(value.name,'"','')}
WITH e, value
CALL db.create.setNodeVectorProperty(e, "description_embedding", value.description_embedding)
CALL apoc.create.addLabels(e, case when coalesce(value.type,"") = "" then [] else [apoc.text.upperCamelCase(replace(value.type,'"',''))] end) yield node
UNWIND value.text_unit_ids AS text_unit
MATCH (c:__Chunk__ {id:text_unit})
MERGE (c)-[:HAS_ENTITY]->(e)
"""

batched_import(entity_statement, entity_df)

rel_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_relationships.parquet',
                         columns=["source", "target", "id", "rank", "weight", "human_readable_id", "description",
                                  "text_unit_ids"])
rel_df.head(2)

rel_statement = """
    MATCH (source:__Entity__ {name:replace(value.source,'"','')})
    MATCH (target:__Entity__ {name:replace(value.target,'"','')})
    // not necessary to merge on id as there is only one relationship per pair
    MERGE (source)-[rel:RELATED {id: value.id}]->(target)
    SET rel += value {.rank, .weight, .human_readable_id, .description, .text_unit_ids}
    RETURN count(*) as createdRels
"""

batched_import(rel_statement, rel_df)

community_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_communities.parquet',
                               columns=["id", "level", "title", "text_unit_ids", "relationship_ids"])

community_df.head(2)

statement = """
MERGE (c:__Community__ {community:value.id})
SET c += value {.level, .title}
/*
UNWIND value.text_unit_ids as text_unit_id
MATCH (t:__Chunk__ {id:text_unit_id})
MERGE (c)-[:HAS_CHUNK]->(t)
WITH distinct c, value
*/
WITH *
UNWIND value.relationship_ids as rel_id
MATCH (start:__Entity__)-[:RELATED {id:rel_id}]->(end:__Entity__)
MERGE (start)-[:IN_COMMUNITY]->(c)
MERGE (end)-[:IN_COMMUNITY]->(c)
RETURn count(distinct c) as createdCommunities
"""

batched_import(statement, community_df)

community_report_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_community_reports.parquet',
                                      columns=["id", "community", "level", "title", "summary", "findings", "rank",
                                               "rank_explanation", "full_content"])
community_report_df.head(2)
# import communities
community_statement = """MATCH (c:__Community__ {community: value.community})
SET c += value {.level, .title, .rank, .rank_explanation, .full_content, .summary}
WITH c, value
UNWIND range(0, size(value.findings)-1) AS finding_idx
WITH c, value, finding_idx, value.findings[finding_idx] as finding
MERGE (c)-[:HAS_FINDING]->(f:Finding {id: finding_idx})
SET f += finding"""
batched_import(community_statement, community_report_df)
# Out:
# create constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique
#
# create constraint document_id if not exists for (d:__Document__) require d.id is unique
#
# create constraint entity_id if not exists for (c:__Community__) require c.community is unique
#
# create constraint entity_id if not exists for (e:__Entity__) require e.id is unique
#
# create constraint entity_title if not exists for (e:__Entity__) require e.name is unique
#
# create constraint entity_title if not exists for (e:__Covariate__) require e.title is unique
#
# create constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique
# {'_contains_updates': True, 'labels_added': 1, 'nodes_created': 1, 'properties_set': 2}
# 1 rows in 0.1479930877685547 s.
# {'_contains_updates': True, 'labels_added': 2, 'relationships_created': 2, 'nodes_created': 2, 'properties_set': 6}
# 2 rows in 0.09875106811523438 s.
# {'_contains_updates': True, 'labels_added': 31, 'relationships_created': 34, 'nodes_created': 31, 'properties_set': 124}
# 31 rows in 0.31952810287475586 s.
# {'_contains_updates': True, 'relationships_created': 15, 'properties_set': 90}
# 15 rows in 0.09972524642944336 s.
# {'_contains_updates': True, 'labels_added': 3, 'relationships_created': 19, 'nodes_created': 3, 'properties_set': 9}
# 3 rows in 0.11859607696533203 s.
# {'_contains_updates': True, 'labels_added': 15, 'relationships_created': 15, 'nodes_created': 15, 'properties_set': 63}
# 3 rows in 0.09711408615112305 s.
# 3

# %% [markdown]
# 访问：http://localhost:7474/browser/。
